# %% [raw]
# Real-time Election Results: Portugal 2019 Data Set
#
# https://archive.ics.uci.edu/ml/datasets/Real-time+Election+Results%3A+Portugal+2019
#
# Data Set Information:
#
# A data set describing the evolution of results in the Portuguese Parliamentary Elections of October 6th 2019.
# The data spans a time interval of 4 hours and 25 minutes, in intervals of 5 minutes, concerning the results of
# the 27 parties involved in the electoral event.
# The data set is tailored for predictive modelling tasks, mostly focused on numerical forecasting tasks.
# Regardless, it allows for other tasks such as ordinal regression or learn-to-rankProvide a short description of
# your data set (less than 200 characters).
#
# Additional (and updated) information may be found in [Web Link] :
# - Raw data sets
# - R code to build the final data set
# - Basic operations to build predictive modelling tasks using this data set
#
# Attribute Information:
#
# TimeElapsed (Numeric): Time (minutes) passed since the first data acquisition
# time (timestamp): Date and time of the data acquisition
# territoryName (string): Short name of the location (district or nation-wide)
# totalMandates (numeric): MP's elected at the moment
# availableMandates (numeric): MP's left to elect at the moment
# numParishes (numeric): Total number of parishes in this location
# numParishesApproved (numeric): Number of parishes approved in this location
# blankVotes (numeric): Number of blank votes
# blankVotesPercentage (numeric): Percentage of blank votes
# nullVotes (numeric): Number of null votes
# nullVotesPercentage (numeric): Percentage of null votes
# votersPercentage (numeric): Percentage of voters
# subscribedVoters (numeric): Number of subscribed voters in the location
# totalVoters (numeric): Percentage of blank votes
# pre.blankVotes (numeric): Number of blank votes (previous election)
# pre.blankVotesPercentage (numeric): Percentage of blank votes (previous election)
# pre.nullVotes (numeric): Number of null votes (previous election)
# pre.nullVotesPercentage (numeric): Percentage of null votes (previous election)
# pre.votersPercentage (numeric): Percentage of voters (previous election)
# pre.subscribedVoters (numeric): Number of subscribed voters in the location (previous election)
# pre.totalVoters (numeric): Percentage of blank votes (previous election)
# Party (string): Political Party
# Mandates (numeric): MP's elected at the moment for the party in a given district
# Percentage (numeric): Percentage of votes in a party
# validVotesPercentage (numeric): Percentage of valid votes in a party
# Votes (numeric): Percentage of party votes
# Hondt (numeric): Number of MP's according to the distribution of votes now
# FinalMandates (numeric): Target: final number of elected MP's in a district/national-level

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('ElectionData.csv')#,parse_dates=['Date']
df
# Out:
#        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                    226         3092                 1081        9652
# 1                    226         3092                 1081        9652
# 2                    226         3092                 1081        9652
# 3                    226         3092                 1081        9652
# 4                    226         3092                 1081        9652
# ...                  ...          ...                  ...         ...
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                      2.50       8874  ...                 52.66
# 1                      2.50       8874  ...                 52.66
# 2                      2.50       8874  ...                 52.66
# 3                      2.50       8874  ...                 52.66
# 4                      2.50       8874  ...                 52.66
# ...                     ...        ...  ...                   ...
# 21638                  2.81       3700  ...                 51.28
# 21639                  2.81       3700  ...                 51.28
# 21640                  2.81       3700  ...                 51.28
# 21641                  2.81       3700  ...                 51.28
# 21642                  2.81       3700  ...                 51.28
#
#        pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                    813743           428546       PS         0       38.29
# 1                    813743           428546  PPD/PSD         0       33.28
# 2                    813743           428546     B.E.         0        6.81
# 3                    813743           428546   CDS-PP         0        4.90
# 4                    813743           428546  PCP-PEV         0        4.59
# ...                     ...              ...      ...       ...         ...
# 21638                371931           190712       NC         0        0.19
# 21639                371931           190712      PNR         0        0.18
# 21640                371931           190712      MPT         0        0.14
# 21641                371931           190712      PTP         0        0.13
# 21642                371931           190712      JPP         0        0.07
#
#        validVotesPercentage   Votes  Hondt  FinalMandates
# 0                     40.22  147993     94            106
# 1                     34.95  128624     81             77
# 2                      7.15   26307     16             19
# 3                      5.14   18923     12              5
# 4                      4.83   17757     11             12
# ...                     ...     ...    ...            ...
# 21638                  0.20     332      0              0
# 21639                  0.19     326      0              0
# 21640                  0.15     256      0              0
# 21641                  0.14     239      0              0
# 21642                  0.07     118      0              0
#
# [21643 rows x 28 columns]

# %%
#df=pd.read_csv('votes_parishes.csv')#,parse_dates=['Date']
#df=pd.read_csv('votes.csv')#,parse_dates=['Date']
#df=pd.read_csv('parishes.csv')#,parse_dates=['Date']
#df=pd.read_csv('overall_results.csv')#,parse_dates=['Date']

# %% [raw]
# FinalMandates-->Target variable

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
#  13  totalVoters               21643 non-null  int64
#  14  pre.blankVotes            21643 non-null  int64
#  15  pre.blankVotesPercentage  21643 non-null  float64
#  16  pre.nullVotes             21643 non-null  int64
#  17  pre.nullVotesPercentage   21643 non-null  float64
#  18  pre.votersPercentage      21643 non-null  float64
#  19  pre.subscribedVoters      21643 non-null  int64
#  20  pre.totalVoters           21643 non-null  int64
#  21  Party                     21643 non-null  object
#  22  Mandates                  21643 non-null  int64
#  23  Percentage                21643 non-null  float64
#  24  validVotesPercentage      21643 non-null  float64
#  25  Votes                     21643 non-null  int64
#  26  Hondt                     21643 non-null  int64
#  27  FinalMandates             21643 non-null  int64
# dtypes: float64(8), int64(17), object(3)
# memory usage: 4.6+ MB

# %%
#dtypes: float64(8), int64(17), object(3)

# %%
df.describe(include='all')
# Out:
#          TimeElapsed                 time territoryName  totalMandates  \
# count   21643.000000                21643         21643   21643.000000
# unique           NaN                   54            21            NaN
# top              NaN  2019-10-06 21:55:01         Porto            NaN
# freq             NaN                  403          1134            NaN
# mean      133.146052                  NaN           NaN      11.544795
# std        77.651193                  NaN           NaN      31.314567
# min         0.000000                  NaN           NaN       0.000000
# 25%        65.000000                  NaN           NaN       1.000000
# 50%       135.000000                  NaN           NaN       4.000000
# 75%       200.000000                  NaN           NaN       9.000000
# max       265.000000                  NaN           NaN     226.000000
#
#         availableMandates   numParishes  numParishesApproved     blankVotes  \
# count        21643.000000  21643.000000         21643.000000   21643.000000
# unique                NaN           NaN                  NaN            NaN
# top                   NaN           NaN                  NaN            NaN
# freq                  NaN           NaN                  NaN            NaN
# mean            11.499284    309.956013           261.090237    8875.066673
# std             31.738783    659.055911           583.377428   21484.874088
# min              0.000000     54.000000             3.000000      19.000000
# 25%              0.000000     75.000000            67.000000    1188.000000
# 50%              3.000000    147.000000           120.000000    2998.000000
# 75%              9.000000    242.000000           208.000000    6889.000000
# max            226.000000   3092.000000          3092.000000  129599.000000
#
#         blankVotesPercentage     nullVotes  ...  pre.votersPercentage  \
# count           21643.000000  21643.000000  ...          21643.000000
# unique                   NaN           NaN  ...                   NaN
# top                      NaN           NaN  ...                   NaN
# freq                     NaN           NaN  ...                   NaN
# mean                2.621629   6148.068752  ...             54.549372
# std                 0.795289  14735.469269  ...              4.964948
# min                 0.530000     39.000000  ...             40.870000
# 25%                 2.230000   1094.000000  ...             51.210000
# 50%                 2.640000   2232.000000  ...             56.260000
# 75%                 2.980000   4121.000000  ...             58.220000
# max                 5.460000  88539.000000  ...             62.580000
#
#         pre.subscribedVoters  pre.totalVoters  Party      Mandates  \
# count           2.164300e+04     2.164300e+04  21643  21643.000000
# unique                   NaN              NaN     21           NaN
# top                      NaN              NaN   B.E.           NaN
# freq                     NaN              NaN   1127           NaN
# mean            6.378503e+05     3.594932e+05    NaN      0.565495
# std             1.544418e+06     8.763729e+05    NaN      4.421804
# min             6.383000e+03     3.215000e+03    NaN      0.000000
# 25%             1.289260e+05     6.964400e+04    NaN      0.000000
# 50%             2.284970e+05     1.102730e+05    NaN      0.000000
# 75%             3.933140e+05     2.276200e+05    NaN      0.000000
# max             9.439701e+06     5.380451e+06    NaN    106.000000
#
#           Percentage  validVotesPercentage         Votes         Hondt  \
# count   21643.000000          21643.000000  2.164300e+04  21643.000000
# unique           NaN                   NaN           NaN           NaN
# top              NaN                   NaN           NaN           NaN
# freq             NaN                   NaN           NaN           NaN
# mean        4.968484              5.207232  1.585209e+04      1.126138
# std        10.379967             10.881108  9.310605e+04      6.293552
# min         0.020000              0.020000  1.000000e+00      0.000000
# 25%         0.220000              0.230000  2.360000e+02      0.000000
# 50%         0.620000              0.650000  7.900000e+02      0.000000
# 75%         3.010000              3.160000  4.510000e+03      0.000000
# max        49.110000             51.420000  1.866407e+06     94.000000
#
#         FinalMandates
# count    21643.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         1.126138
# std          6.872644
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        106.000000
#
# [11 rows x 28 columns]

# %%
for col in df.columns:
    if df[col].dtype=="object":
        print(df[col].value_counts())
        print()
# Out:
# 2019-10-06 21:55:01    403
# 2019-10-06 22:35:01    403
# 2019-10-06 21:15:02    403
# 2019-10-06 23:05:01    403
# 2019-10-06 21:35:01    403
# 2019-10-06 22:20:02    403
# 2019-10-06 22:15:01    403
# 2019-10-06 23:45:02    403
# 2019-10-07 00:00:02    403
# 2019-10-06 21:00:01    403
# 2019-10-06 21:40:02    403
# 2019-10-07 00:30:02    403
# 2019-10-06 22:30:01    403
# 2019-10-07 00:35:01    403
# 2019-10-06 21:50:01    403
# 2019-10-06 21:05:01    403
# 2019-10-06 21:20:02    403
# 2019-10-06 23:20:01    403
# 2019-10-06 23:00:01    403
# 2019-10-06 22:10:01    403
# 2019-10-06 22:25:01    403
# 2019-10-07 00:25:01    403
# 2019-10-07 00:05:01    403
# 2019-10-06 23:10:02    403
# 2019-10-06 20:50:01    403
# 2019-10-06 21:30:01    403
# 2019-10-07 00:10:02    403
# 2019-10-06 23:25:02    403
# 2019-10-06 22:45:01    403
# 2019-10-06 20:55:01    403
# 2019-10-06 23:40:01    403
# 2019-10-06 23:55:01    403
# 2019-10-06 21:45:02    403
# 2019-10-06 22:50:01    403
# 2019-10-06 22:40:02    403
# 2019-10-06 22:05:02    403
# 2019-10-06 23:15:01    403
# 2019-10-07 00:20:02    403
# 2019-10-06 22:55:02    403
# 2019-10-06 23:50:02    403
# 2019-10-06 21:25:02    403
# 2019-10-06 20:45:02    403
# 2019-10-06 21:10:01    403
# 2019-10-06 22:00:02    403
# 2019-10-06 23:30:01    403
# 2019-10-06 23:35:02    403
# 2019-10-07 00:15:01    403
# 2019-10-06 20:35:02    386
# 2019-10-06 20:10:02    386
# 2019-10-06 20:15:02    386
# 2019-10-06 20:20:02    386
# 2019-10-06 20:40:02    386
# 2019-10-06 20:30:02    386
# 2019-10-06 20:25:02    386
# Name: time, dtype: int64
#
# Porto                  1134
# Território Nacional    1134
# Leiria                 1134
# Braga                  1134
# Coimbra                1080
# Madeira                1080
# Viana do Castelo       1080
# Lisboa                 1080
# Aveiro                 1080
# Viseu                  1080
# Setúbal                1080
# Évora                  1026
# Guarda                 1026
# Faro                   1026
# Santarém               1026
# Castelo Branco          972
# Bragança                972
# Beja                    918
# Portalegre              918
# Vila Real               864
# Açores                  799
# Name: territoryName, dtype: int64
#
# B.E.         1127
# PS           1127
# PCTP/MRPP    1127
# PNR          1127
# PDR          1127
# A            1127
# IL           1127
# PAN          1127
# L            1127
# CDS-PP       1127
# PPD/PSD      1127
# PCP-PEV      1127
# CH           1127
# PPM          1073
# R.I.R.       1026
# MPT          1019
# PTP          1019
# PURP          972
# NC            972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
df['FinalMandates'].value_counts()
# Out:
# 0      17823
# 1       1134
# 2        695
# 3        641
# 4        378
# 5        270
# 8        108
# 12       108
# 7         54
# 6         54
# 77        54
# 20        54
# 19        54
# 9         54
# 106       54
# 17        54
# 15        54
# Name: FinalMandates, dtype: int64

# %%
#Classification?

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(), annot=True)

# %% [raw]
# ?????????????????????????????????????????????????????????????????

# %%
# multicolinearity

# %%
#Multicollinearity occurs when two or more independent variables are highly correlated with one another in a regression model
#This means that an independent variable can be predicted from another independent variable in a regression model

# %% [raw]
# Avoiding multicollinearity

# %% [raw]
# #from statsmodels.stats.outliers_influence import variance_inflation_factor
# #def calc_vif(df):
#
#     # Calculating VIF
#     vif = pd.DataFrame()
#     vif["variables"] = X.columns
#     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#
#     return(vif)

# %% [markdown]
# Dropping the multicollinear columns

# %%
#df.drop(['totalMandates','numParishesApproved','blankVotes','nullVotes','subscribedVoters','totalVoters','pre.blankVotes','pre.nullVotes','pre.subscribedVoters','pre.totalVoters','Percentage','Mandates','pre.blankVotesPercentage','pre.votersPercentage'],axis=1,inplace=True)

# %%
#I got to know it does not effect the target variable

# %%
#its confusing to delete the columns

# %%
#checking null values

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %% [markdown]
# #LABELENCODING

# %%
df['Dates'] = pd.to_datetime(df['time']).dt.date
df['Time'] = pd.to_datetime(df['time']).dt.time

# %%
df.drop(['time'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype=="object":
        df[col]=LabelEncoder().fit_transform(df[col])

# %%
df
# Out:
#        TimeElapsed  territoryName  totalMandates  availableMandates  \
# 0                0             16              0                226
# 1                0             16              0                226
# 2                0             16              0                226
# 3                0             16              0                226
# 4                0             16              0                226
# ...            ...            ...            ...                ...
# 21638          265             19              8                  0
# 21639          265             19              8                  0
# 21640          265             19              8                  0
# 21641          265             19              8                  0
# 21642          265             19              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0             3092                 1081        9652                  2.50
# 1             3092                 1081        9652                  2.50
# 2             3092                 1081        9652                  2.50
# 3             3092                 1081        9652                  2.50
# 4             3092                 1081        9652                  2.50
# ...            ...                  ...         ...                   ...
# 21638          277                  277        4995                  2.81
# 21639          277                  277        4995                  2.81
# 21640          277                  277        4995                  2.81
# 21641          277                  277        4995                  2.81
# 21642          277                  277        4995                  2.81
#
#        nullVotes  nullVotesPercentage  ...  pre.totalVoters  Party  Mandates  \
# 0           8874                 2.30  ...           428546     17         0
# 1           8874                 2.30  ...           428546     15         0
# 2           8874                 2.30  ...           428546      1         0
# 3           8874                 2.30  ...           428546      2         0
# 4           8874                 2.30  ...           428546     11         0
# ...          ...                  ...  ...              ...    ...       ...
# 21638       3700                 2.08  ...           190712      9         0
# 21639       3700                 2.08  ...           190712     14         0
# 21640       3700                 2.08  ...           190712      8         0
# 21641       3700                 2.08  ...           190712     18         0
# 21642       3700                 2.08  ...           190712      5         0
#
#        Percentage  validVotesPercentage   Votes  Hondt  FinalMandates  Dates  \
# 0           38.29                 40.22  147993     94            106      0
# 1           33.28                 34.95  128624     81             77      0
# 2            6.81                  7.15   26307     16             19      0
# 3            4.90                  5.14   18923     12              5      0
# 4            4.59                  4.83   17757     11             12      0
# ...           ...                   ...     ...    ...            ...    ...
# 21638        0.19                  0.20     332      0              0      1
# 21639        0.18                  0.19     326      0              0      1
# 21640        0.14                  0.15     256      0              0      1
# 21641        0.13                  0.14     239      0              0      1
# 21642        0.07                  0.07     118      0              0      1
#
#        Time
# 0         8
# 1         8
# 2         8
# 3         8
# 4         8
# ...     ...
# 21638     7
# 21639     7
# 21640     7
# 21641     7
# 21642     7
#
# [21643 rows x 29 columns]

# %%
df.corr()
# Out:
#                           TimeElapsed  territoryName  totalMandates  \
# TimeElapsed                  1.000000      -0.012674       0.260377
# territoryName               -0.012674       1.000000       0.172374
# totalMandates                0.260377       0.172374       1.000000
# availableMandates           -0.261627       0.181563       0.217404
# numParishes                 -0.001944       0.223300       0.765877
# numParishesApproved          0.100432       0.215599       0.873415
# blankVotes                   0.192350       0.178082       0.969988
# blankVotesPercentage         0.034343      -0.302412      -0.003149
# nullVotes                    0.185784       0.196554       0.967294
# nullVotesPercentage         -0.225021      -0.126432      -0.165132
# votersPercentage             0.029698       0.104222       0.171317
# subscribedVoters             0.195487       0.195483       0.974407
# totalVoters                  0.198243       0.193847       0.976336
# pre.blankVotes               0.195734       0.182412       0.973357
# pre.blankVotesPercentage     0.093739      -0.288817       0.034774
# pre.nullVotes                0.189902       0.200393       0.969992
# pre.nullVotesPercentage     -0.106054      -0.083214      -0.132143
# pre.votersPercentage         0.054761       0.078855       0.151927
# pre.subscribedVoters         0.193160       0.196979       0.972976
# pre.totalVoters              0.196667       0.195102       0.975404
# Party                       -0.001169       0.012263      -0.003111
# Mandates                     0.090190       0.057823       0.336989
# Percentage                   0.000767      -0.003433      -0.010171
# validVotesPercentage         0.000526      -0.004874      -0.010474
# Votes                        0.082417       0.078520       0.395617
# Hondt                       -0.001100       0.084131       0.288420
# FinalMandates               -0.001007       0.077042       0.264117
# Dates                        0.616137      -0.003485       0.136754
# Time                         0.236346      -0.008330       0.090744
#
#                           availableMandates  numParishes  numParishesApproved  \
# TimeElapsed                       -0.261627    -0.001944             0.100432
# territoryName                      0.181563     0.223300             0.215599
# totalMandates                      0.217404     0.765877             0.873415
# availableMandates                  1.000000     0.745472             0.562719
# numParishes                        0.745472     1.000000             0.954092
# numParishesApproved                0.562719     0.954092             1.000000
# blankVotes                         0.390638     0.861279             0.951265
# blankVotesPercentage              -0.002806     0.032013             0.035153
# nullVotes                          0.407366     0.870240             0.956142
# nullVotesPercentage                0.029915     0.013209            -0.037416
# votersPercentage                   0.112293     0.073855             0.081157
# subscribedVoters                   0.385828     0.856855             0.946191
# totalVoters                        0.379093     0.850881             0.940941
# pre.blankVotes                     0.383877     0.856779             0.947190
# pre.blankVotesPercentage          -0.008966     0.036461             0.050378
# pre.nullVotes                      0.399074     0.864837             0.951899
# pre.nullVotesPercentage           -0.044174    -0.058017            -0.073301
# pre.votersPercentage               0.080524     0.026407             0.042180
# pre.subscribedVoters               0.391272     0.860782             0.949110
# pre.totalVoters                    0.383089     0.853779             0.943147
# Party                             -0.001882    -0.004013            -0.003765
# Mandates                           0.072320     0.257365             0.293795
# Percentage                        -0.011083    -0.010770            -0.009840
# validVotesPercentage              -0.011052    -0.010624            -0.009767
# Votes                              0.152348     0.343593             0.380311
# Hondt                              0.291310     0.359283             0.340901
# FinalMandates                      0.266764     0.329009             0.312177
# Dates                             -0.136227    -0.000534             0.034277
# Time                              -0.092640    -0.001277             0.057789
#
#                           blankVotes  blankVotesPercentage  nullVotes  \
# TimeElapsed                 0.192350              0.034343   0.185784
# territoryName               0.178082             -0.302412   0.196554
# totalMandates               0.969988             -0.003149   0.967294
# availableMandates           0.390638             -0.002806   0.407366
# numParishes                 0.861279              0.032013   0.870240
# numParishesApproved         0.951265              0.035153   0.956142
# blankVotes                  1.000000              0.038503   0.998781
# blankVotesPercentage        0.038503              1.000000   0.006615
# nullVotes                   0.998781              0.006615   1.000000
# nullVotesPercentage        -0.150894              0.094047  -0.136296
# votersPercentage            0.183970             -0.190778   0.181411
# subscribedVoters            0.998297              0.001598   0.998988
# totalVoters                 0.997951             -0.002062   0.998405
# pre.blankVotes              0.999657              0.030061   0.998883
# pre.blankVotesPercentage    0.072183              0.959142   0.041317
# pre.nullVotes               0.997490             -0.006067   0.999298
# pre.nullVotesPercentage    -0.150275             -0.307544  -0.125639
# pre.votersPercentage        0.161642             -0.105314   0.154965
# pre.subscribedVoters        0.998487              0.002821   0.999296
# pre.totalVoters             0.998178             -0.000069   0.998706
# Party                      -0.003826             -0.019692  -0.003172
# Mandates                    0.326630             -0.000926   0.325711
# Percentage                 -0.011883             -0.006258  -0.011602
# validVotesPercentage       -0.012002             -0.002076  -0.011820
# Votes                       0.404003             -0.001486   0.404195
# Hondt                       0.322780             -0.001305   0.326144
# FinalMandates               0.295583             -0.001195   0.298663
# Dates                       0.082068              0.001354   0.079072
# Time                        0.090423              0.032550   0.087577
#
#                           nullVotesPercentage  ...  pre.totalVoters     Party  \
# TimeElapsed                         -0.225021  ...         0.196667 -0.001169
# territoryName                       -0.126432  ...         0.195102  0.012263
# totalMandates                       -0.165132  ...         0.975404 -0.003111
# availableMandates                    0.029915  ...         0.383089 -0.001882
# numParishes                          0.013209  ...         0.853779 -0.004013
# numParishesApproved                 -0.037416  ...         0.943147 -0.003765
# blankVotes                          -0.150894  ...         0.998178 -0.003826
# blankVotesPercentage                 0.094047  ...        -0.000069 -0.019692
# nullVotes                           -0.136296  ...         0.998706 -0.003172
# nullVotesPercentage                  1.000000  ...        -0.159566  0.007069
# votersPercentage                    -0.108855  ...         0.186834  0.014657
# subscribedVoters                    -0.157263  ...         0.999841 -0.003240
# totalVoters                         -0.161816  ...         0.999952 -0.003079
# pre.blankVotes                      -0.152234  ...         0.999085 -0.003586
# pre.blankVotesPercentage             0.100924  ...         0.035404 -0.016434
# pre.nullVotes                       -0.141809  ...         0.998879 -0.002885
# pre.nullVotesPercentage              0.497749  ...        -0.139431  0.009577
# pre.votersPercentage                -0.233688  ...         0.165287  0.012210
# pre.subscribedVoters                -0.153891  ...         0.999725 -0.003254
# pre.totalVoters                     -0.159566  ...         1.000000 -0.003078
# Party                                0.007069  ...        -0.003078  1.000000
# Mandates                            -0.056254  ...         0.328527  0.092855
# Percentage                           0.003301  ...        -0.011453  0.232081
# validVotesPercentage                 0.005441  ...        -0.011737  0.232066
# Votes                               -0.066526  ...         0.404976  0.077322
# Hondt                               -0.032388  ...         0.322329  0.104713
# FinalMandates                       -0.029659  ...         0.295169  0.105097
# Dates                               -0.081751  ...         0.087053 -0.000321
# Time                                -0.123368  ...         0.088575 -0.000768
#
#                           Mandates  Percentage  validVotesPercentage  \
# TimeElapsed               0.090190    0.000767              0.000526
# territoryName             0.057823   -0.003433             -0.004874
# totalMandates             0.336989   -0.010171             -0.010474
# availableMandates         0.072320   -0.011083             -0.011052
# numParishes               0.257365   -0.010770             -0.010624
# numParishesApproved       0.293795   -0.009840             -0.009767
# blankVotes                0.326630   -0.011883             -0.012002
# blankVotesPercentage     -0.000926   -0.006258             -0.002076
# nullVotes                 0.325711   -0.011602             -0.011820
# nullVotesPercentage      -0.056254    0.003301              0.005441
# votersPercentage          0.056553   -0.019836             -0.020966
# subscribedVoters          0.328197   -0.011276             -0.011548
# totalVoters               0.328836   -0.011560             -0.011856
# pre.blankVotes            0.327807   -0.011719             -0.011872
# pre.blankVotesPercentage  0.011932   -0.008944             -0.004922
# pre.nullVotes             0.326680   -0.011332             -0.011607
# pre.nullVotesPercentage  -0.044964    0.000391              0.000158
# pre.votersPercentage      0.050533   -0.012054             -0.013078
# pre.subscribedVoters      0.327703   -0.011279             -0.011540
# pre.totalVoters           0.328527   -0.011453             -0.011737
# Party                     0.092855    0.232081              0.232066
# Mandates                  1.000000    0.312402              0.311762
# Percentage                0.312402    1.000000              0.999944
# validVotesPercentage      0.311762    0.999944              1.000000
# Votes                     0.972310    0.327706              0.327054
# Hondt                     0.791960    0.401192              0.400857
# FinalMandates             0.814370    0.383086              0.382744
# Dates                     0.047246    0.000276              0.000147
# Time                      0.031585    0.000424              0.000343
#
#                              Votes     Hondt  FinalMandates     Dates  \
# TimeElapsed               0.082417 -0.001100      -0.001007  0.616137
# territoryName             0.078520  0.084131       0.077042 -0.003485
# totalMandates             0.395617  0.288420       0.264117  0.136754
# availableMandates         0.152348  0.291310       0.266764 -0.136227
# numParishes               0.343593  0.359283       0.329009 -0.000534
# numParishesApproved       0.380311  0.340901       0.312177  0.034277
# blankVotes                0.404003  0.322780       0.295583  0.082068
# blankVotesPercentage     -0.001486 -0.001305      -0.001195  0.001354
# nullVotes                 0.404195  0.326144       0.298663  0.079072
# nullVotesPercentage      -0.066526 -0.032388      -0.029659 -0.081751
# votersPercentage          0.076377  0.066665       0.061048  0.014714
# subscribedVoters          0.404861  0.322750       0.295555  0.085861
# totalVoters               0.404996  0.321587       0.294490  0.087859
# pre.blankVotes            0.404458  0.321997       0.294866  0.084954
# pre.blankVotesPercentage  0.013206  0.006242       0.005716  0.023851
# pre.nullVotes             0.404354  0.324854       0.297482  0.082223
# pre.nullVotesPercentage  -0.057086 -0.042245      -0.038686 -0.038556
# pre.votersPercentage      0.067619  0.055092       0.050450  0.022683
# pre.subscribedVoters      0.404765  0.323704       0.296428  0.084621
# pre.totalVoters           0.404976  0.322329       0.295169  0.087053
# Party                     0.077322  0.104713       0.105097 -0.000321
# Mandates                  0.972310  0.791960       0.814370  0.047246
# Percentage                0.327706  0.401192       0.383086  0.000276
# validVotesPercentage      0.327054  0.400857       0.382744  0.000147
# Votes                     1.000000  0.872658       0.882502  0.036539
# Hondt                     0.872658  1.000000       0.994480 -0.000302
# FinalMandates             0.882502  0.994480       1.000000 -0.000277
# Dates                     0.036539 -0.000302      -0.000277  1.000000
# Time                      0.037047 -0.000723      -0.000662 -0.619702
#
#                               Time
# TimeElapsed               0.236346
# territoryName            -0.008330
# totalMandates             0.090744
# availableMandates        -0.092640
# numParishes              -0.001277
# numParishesApproved       0.057789
# blankVotes                0.090423
# blankVotesPercentage      0.032550
# nullVotes                 0.087577
# nullVotesPercentage      -0.123368
# votersPercentage          0.011441
# subscribedVoters          0.088870
# totalVoters               0.089150
# pre.blankVotes            0.090234
# pre.blankVotesPercentage  0.063981
# pre.nullVotes             0.087792
# pre.nullVotesPercentage  -0.058113
# pre.votersPercentage      0.026583
# pre.subscribedVoters      0.088080
# pre.totalVoters           0.088575
# Party                    -0.000768
# Mandates                  0.031585
# Percentage                0.000424
# validVotesPercentage      0.000343
# Votes                     0.037047
# Hondt                    -0.000723
# FinalMandates            -0.000662
# Dates                    -0.619702
# Time                      1.000000
#
# [29 rows x 29 columns]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[ 1.71470808,  0.98296816,  0.36868023, ..., 15.25996213,
#          0.41837381,  1.19248297],
#        [ 1.71470808,  0.98296816,  0.36868023, ..., 11.04023671,
#          0.41837381,  1.19248297],
#        [ 1.71470808,  0.98296816,  0.36868023, ...,  2.60078588,
#          0.41837381,  1.19248297],
#        ...,
#        [ 1.69806785,  1.48421407,  0.11320217, ...,  0.1638618 ,
#          2.39020696,  1.25664593],
#        [ 1.69806785,  1.48421407,  0.11320217, ...,  0.1638618 ,
#          2.39020696,  1.25664593],
#        [ 1.69806785,  1.48421407,  0.11320217, ...,  0.1638618 ,
#          2.39020696,  1.25664593]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    0,     0,     0, ..., 21608, 21623, 21623], dtype=int64), array([ 3,  4, 22, ..., 23, 22, 23], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#        TimeElapsed  territoryName  totalMandates  availableMandates  \
# 22               0              0              0                 16
# 23               0              0              0                 16
# 24               0              0              0                 16
# 25               0              0              0                 16
# 26               0              0              0                 16
# ...            ...            ...            ...                ...
# 21638          265             19              8                  0
# 21639          265             19              8                  0
# 21640          265             19              8                  0
# 21641          265             19              8                  0
# 21642          265             19              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 22             147                   12         186                  2.92
# 23             147                   12         186                  2.92
# 24             147                   12         186                  2.92
# 25             147                   12         186                  2.92
# 26             147                   12         186                  2.92
# ...            ...                  ...         ...                   ...
# 21638          277                  277        4995                  2.81
# 21639          277                  277        4995                  2.81
# 21640          277                  277        4995                  2.81
# 21641          277                  277        4995                  2.81
# 21642          277                  277        4995                  2.81
#
#        nullVotes  nullVotesPercentage  ...  pre.totalVoters  Party  Mandates  \
# 22           101                 1.59  ...             6826     17         0
# 23           101                 1.59  ...             6826      1         0
# 24           101                 1.59  ...             6826      2         0
# 25           101                 1.59  ...             6826     11         0
# 26           101                 1.59  ...             6826     10         0
# ...          ...                  ...  ...              ...    ...       ...
# 21638       3700                 2.08  ...           190712      9         0
# 21639       3700                 2.08  ...           190712     14         0
# 21640       3700                 2.08  ...           190712      8         0
# 21641       3700                 2.08  ...           190712     18         0
# 21642       3700                 2.08  ...           190712      5         0
#
#        Percentage  validVotesPercentage  Votes  Hondt  FinalMandates  Dates  \
# 22          34.33                 35.95   2187      7              7      0
# 23           7.47                  7.82    476      1              2      0
# 24           6.14                  6.43    391      1              1      0
# 25           2.39                  2.50    152      0              0      0
# 26           2.04                  2.14    130      0              0      0
# ...           ...                   ...    ...    ...            ...    ...
# 21638        0.19                  0.20    332      0              0      1
# 21639        0.18                  0.19    326      0              0      1
# 21640        0.14                  0.15    256      0              0      1
# 21641        0.13                  0.14    239      0              0      1
# 21642        0.07                  0.07    118      0              0      1
#
#        Time
# 22        8
# 23        8
# 24        8
# 25        8
# 26        8
# ...     ...
# 21638     7
# 21639     7
# 21640     7
# 21641     7
# 21642     7
#
# [18333 rows x 29 columns]

# %%
df.shape
# Out:
# (21643, 29)

# %% [markdown]
# # ML

# %%
x=df_new.drop(['FinalMandates'],axis=1) 
y=df_new['FinalMandates']

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
newx=sc.fit_transform(x)
newx
# Out:
# array([[-1.75204539, -1.7413557 , -0.76728184, ...,  4.560088  ,
#         -0.42170474, -1.20623771],
#        [-1.75204539, -1.7413557 , -0.76728184, ...,  0.44503263,
#         -0.42170474, -1.20623771],
#        [-1.75204539, -1.7413557 , -0.76728184, ...,  0.44503263,
#         -0.42170474, -1.20623771],
#        ...,
#        [ 1.6913844 ,  1.50873516,  0.22949065, ..., -0.24080994,
#          2.3713274 , -1.27035267],
#        [ 1.6913844 ,  1.50873516,  0.22949065, ..., -0.24080994,
#          2.3713274 , -1.27035267],
#        [ 1.6913844 ,  1.50873516,  0.22949065, ..., -0.24080994,
#          2.3713274 , -1.27035267]])

# %%
y
# Out:
# 22       7
# 23       2
# 24       1
# 25       0
# 26       0
#         ..
# 21638    0
# 21639    0
# 21640    0
# 21641    0
# 21642    0
# Name: FinalMandates, Length: 18333, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,newx,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(newx, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,newx,y):
    c_scores=cross_val_score(model,newx,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
final_r_state=maxr2_score(lnr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.9847312620113952
# r2 score corresponding to  43  is  0.9874410085872279
# r2 score corresponding to  44  is  0.9879500833820266
# r2 score corresponding to  45  is  0.985063183805881
# r2 score corresponding to  46  is  0.9875567143953886
# r2 score corresponding to  47  is  0.9905662669826143
# r2 score corresponding to  48  is  0.9839364409209612
# r2 score corresponding to  49  is  0.9831247618645589
# r2 score corresponding to  50  is  0.9852491491189237
# r2 score corresponding to  51  is  0.9837977606854508
# r2 score corresponding to  52  is  0.9844462343173387
# r2 score corresponding to  53  is  0.9862894047544116
# r2 score corresponding to  54  is  0.9810074255475526
# r2 score corresponding to  55  is  0.9822267696785715
# r2 score corresponding to  56  is  0.9872864300149067
# r2 score corresponding to  57  is  0.9836988768069129
# r2 score corresponding to  58  is  0.9860831161138923
# r2 score corresponding to  59  is  0.9826551422339368
# r2 score corresponding to  60  is  0.9857755841480033
# r2 score corresponding to  61  is  0.9885454899196043
# r2 score corresponding to  62  is  0.9845184680328269
# r2 score corresponding to  63  is  0.979603408885674
# r2 score corresponding to  64  is  0.9897725942483263
# r2 score corresponding to  65  is  0.9845992244789749
# r2 score corresponding to  66  is  0.9871781427934706
# r2 score corresponding to  67  is  0.9848720026616432
# r2 score corresponding to  68  is  0.9858608293640664
# r2 score corresponding to  69  is  0.9883945381140719
# r2 score corresponding to  70  is  0.9856071414702791
# r2 score corresponding to  71  is  0.9829578217524008
# r2 score corresponding to  72  is  0.9846373035899886
# r2 score corresponding to  73  is  0.98712721350993
# r2 score corresponding to  74  is  0.9871646259413287
# r2 score corresponding to  75  is  0.9893533062349431
# r2 score corresponding to  76  is  0.9861189228782592
# r2 score corresponding to  77  is  0.9848089322229951
# r2 score corresponding to  78  is  0.9875263174523383
# r2 score corresponding to  79  is  0.9875967757431198
# r2 score corresponding to  80  is  0.9826980992708929
# r2 score corresponding to  81  is  0.9856403255067421
# r2 score corresponding to  82  is  0.9835769950043997
# r2 score corresponding to  83  is  0.9871128286169609
# r2 score corresponding to  84  is  0.9842863342350686
# r2 score corresponding to  85  is  0.9877009185051309
# r2 score corresponding to  86  is  0.9874723633928617
# r2 score corresponding to  87  is  0.9877453486587208
# r2 score corresponding to  88  is  0.9832004433012345
# r2 score corresponding to  89  is  0.9898277946315546
# r2 score corresponding to  90  is  0.9833190928646052
# r2 score corresponding to  91  is  0.9865770064101776
# r2 score corresponding to  92  is  0.986559401148855
# r2 score corresponding to  93  is  0.983303646514316
# r2 score corresponding to  94  is  0.9792246935910313
# r2 score corresponding to  95  is  0.9873267654822484
# r2 score corresponding to  96  is  0.9854613938994227
# r2 score corresponding to  97  is  0.9845317950518014
# r2 score corresponding to  98  is  0.9840153018371107
# r2 score corresponding to  99  is  0.9842245188509167
# max r2 score corresponding to  47  is  0.9905662669826143

# %%
model_evaluation(lnr,newx,y)
# Out:
# Mean r2 score for regressor:  -1.1056866481151449e+24
# standard deviation in r2 score for regressor:  2.2113732962302898e+24
# [ 9.61537310e-01  9.84878362e-01  9.96011781e-01  9.99380082e-01
#  -5.52843324e+24]

# %% [raw]
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.model_selection import GridSearchCV
# parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
# gb_reg=GradientBoostingRegressor()
# reg = GridSearchCV(gb_reg, parameters, cv=5,scoring="r2")
# reg.fit(newx,y)
# reg.best_params_

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_reg=GradientBoostingRegressor(learning_rate=0.1,n_estimators=100)
maxr2_score(gb_reg,newx,y)
# Out:
# r2 score corresponding to  42  is  0.9959816131054429
# r2 score corresponding to  43  is  0.9965177899194738
# r2 score corresponding to  44  is  0.9964870803107158
# r2 score corresponding to  45  is  0.9965330070554843
# r2 score corresponding to  46  is  0.9971148333340346
# r2 score corresponding to  47  is  0.9980653763355045
# r2 score corresponding to  48  is  0.9957860408927741
# r2 score corresponding to  49  is  0.9963957847865604
# r2 score corresponding to  50  is  0.9974118681814471
# r2 score corresponding to  51  is  0.9965106576463423
# r2 score corresponding to  52  is  0.9952471753060221
# r2 score corresponding to  53  is  0.9963347698964116
# r2 score corresponding to  54  is  0.9955291096136023
# r2 score corresponding to  55  is  0.9951202795269761
# r2 score corresponding to  56  is  0.9960972117075565
# r2 score corresponding to  57  is  0.9960093205731597
# r2 score corresponding to  58  is  0.9963503573494611
# r2 score corresponding to  59  is  0.9968802745739745
# r2 score corresponding to  60  is  0.996827095200988
# r2 score corresponding to  61  is  0.9969351553024376
# r2 score corresponding to  62  is  0.996408670608812
# r2 score corresponding to  63  is  0.9964440293341685
# r2 score corresponding to  64  is  0.9974281356444821
# r2 score corresponding to  65  is  0.9973902219990406
# r2 score corresponding to  66  is  0.9970259431153244
# r2 score corresponding to  67  is  0.9968238490331042
# r2 score corresponding to  68  is  0.997188608173081
# r2 score corresponding to  69  is  0.9958147638330568
# r2 score corresponding to  70  is  0.9970461989240934
# r2 score corresponding to  71  is  0.9961102646175438
# r2 score corresponding to  72  is  0.9962958161244977
# r2 score corresponding to  73  is  0.996140568973069
# r2 score corresponding to  74  is  0.9966816853775268
# r2 score corresponding to  75  is  0.997459017521602
# r2 score corresponding to  76  is  0.9967074461015917
# r2 score corresponding to  77  is  0.9965565806343217
# r2 score corresponding to  78  is  0.9973497505048385
# r2 score corresponding to  79  is  0.9954063616197165
# r2 score corresponding to  80  is  0.9960024222138486
# r2 score corresponding to  81  is  0.996129467411287
# r2 score corresponding to  82  is  0.9962357568903661
# r2 score corresponding to  83  is  0.9975320002363746
# r2 score corresponding to  84  is  0.9958119099211051
# r2 score corresponding to  85  is  0.9962494849090704
# r2 score corresponding to  86  is  0.9964844749061114
# r2 score corresponding to  87  is  0.9977799512388188
# r2 score corresponding to  88  is  0.9966867726411797
# r2 score corresponding to  89  is  0.997782789059346
# r2 score corresponding to  90  is  0.9955427382104772
# r2 score corresponding to  91  is  0.99642647409877
# r2 score corresponding to  92  is  0.9961123902678412
# r2 score corresponding to  93  is  0.9966174193367267
# r2 score corresponding to  94  is  0.9963278364814778
# r2 score corresponding to  95  is  0.9970333276675286
# r2 score corresponding to  96  is  0.9968869403582221
# r2 score corresponding to  97  is  0.9964790496826913
# r2 score corresponding to  98  is  0.9963396347575804
# r2 score corresponding to  99  is  0.9964732498375626
# max r2 score corresponding to  47  is  0.9980653763355045
# 47

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,150,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(newx,y)
clf.best_params_

# %%
# Random forest using n_estimators=500 
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=500)
maxr2_score(rfr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.9992260414428167
# r2 score corresponding to  43  is  0.9998338447422376
# r2 score corresponding to  44  is  0.9997247113029403
# r2 score corresponding to  45  is  0.9998832675815545
# r2 score corresponding to  46  is  0.999798929838006
# r2 score corresponding to  47  is  0.999896851166002
# r2 score corresponding to  48  is  0.9990119039172723
# r2 score corresponding to  49  is  0.9997122904295207
# r2 score corresponding to  50  is  0.9995406006201434
# r2 score corresponding to  51  is  0.9990136219486959
# r2 score corresponding to  52  is  0.9996278710030617
# r2 score corresponding to  53  is  0.9996310125075178
# r2 score corresponding to  54  is  0.9997184271193592
# r2 score corresponding to  55  is  0.999358644377239
# r2 score corresponding to  56  is  0.9997198857509468
# r2 score corresponding to  57  is  0.9999720912904642
# r2 score corresponding to  58  is  0.9992494389300385
# r2 score corresponding to  59  is  0.9997291378953612
# r2 score corresponding to  60  is  0.9990530061871851
# r2 score corresponding to  61  is  0.9993883127744648
# r2 score corresponding to  62  is  0.9999276510523396
# r2 score corresponding to  63  is  0.9994024570924398
# r2 score corresponding to  64  is  0.9998508641061223
# r2 score corresponding to  65  is  0.9998670850747705
# r2 score corresponding to  66  is  0.9997903603248064
# r2 score corresponding to  67  is  0.9997157780661814
# r2 score corresponding to  68  is  0.9998784406074163
# r2 score corresponding to  69  is  0.9999306386832199
# r2 score corresponding to  70  is  0.9999639723521214
# r2 score corresponding to  71  is  0.999926707254092
# r2 score corresponding to  72  is  0.9998528547362175
# r2 score corresponding to  73  is  0.9998076706349392
# r2 score corresponding to  74  is  0.9998392602464566
# r2 score corresponding to  75  is  0.9996504448415309
# r2 score corresponding to  76  is  0.9997168578753722
# r2 score corresponding to  77  is  0.999772430777562
# r2 score corresponding to  78  is  0.999716971302803
# r2 score corresponding to  79  is  0.9995842404163514
# r2 score corresponding to  80  is  0.9999081624941323
# r2 score corresponding to  81  is  0.9994255213483081
# r2 score corresponding to  82  is  0.9999325781998899
# r2 score corresponding to  83  is  0.9998594148743623
# r2 score corresponding to  84  is  0.9993656035968157
# r2 score corresponding to  85  is  0.9992743649401499
# r2 score corresponding to  86  is  0.9992117710348696
# r2 score corresponding to  87  is  0.9999487335056396
# r2 score corresponding to  88  is  0.9999152228150787
# r2 score corresponding to  89  is  0.9998714069982259
# r2 score corresponding to  90  is  0.9997245994647302
# r2 score corresponding to  91  is  0.9998695535241325
# r2 score corresponding to  92  is  0.999558954767146
# r2 score corresponding to  93  is  0.999859956884266
# r2 score corresponding to  94  is  0.9998328234051262
# r2 score corresponding to  95  is  0.9999559773924064
# r2 score corresponding to  96  is  0.999347936096746
# r2 score corresponding to  97  is  0.9993802574335352
# r2 score corresponding to  98  is  0.9993196257939831
# r2 score corresponding to  99  is  0.999213410171829
# max r2 score corresponding to  57  is  0.9999720912904642
# 57

# %%
model_evaluation(rfr,newx,y)
# Out:
# Mean r2 score for regressor:  0.98570017998368
# standard deviation in r2 score for regressor:  0.026028771147859536
# [0.93373934 0.99568544 0.9990956  0.99999976 0.99998076]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
parameters = {"n_neighbors":range(2,30)}
clf = GridSearchCV(knr, parameters, cv=5,scoring="r2")
clf.fit(newx, y)
clf.best_params_
# Out:
# {'n_neighbors': 2}

# %%
knr=KNeighborsRegressor(n_neighbors=2)
maxr2_score(knr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.998627065805546
# r2 score corresponding to  43  is  0.9993772312436648
# r2 score corresponding to  44  is  0.9984484351869682
# r2 score corresponding to  45  is  0.9995125338315081
# r2 score corresponding to  46  is  0.9991690428138789
# r2 score corresponding to  47  is  0.9990749201582109
# r2 score corresponding to  48  is  0.9984569228452205
# r2 score corresponding to  49  is  0.9988310146647944
# r2 score corresponding to  50  is  0.9988876964260067
# r2 score corresponding to  51  is  0.9985412329955053
# r2 score corresponding to  52  is  0.9992139691844625
# r2 score corresponding to  53  is  0.9990180250410606
# r2 score corresponding to  54  is  0.9992550193654334
# r2 score corresponding to  55  is  0.9988033215577281
# r2 score corresponding to  56  is  0.9988343036225985
# r2 score corresponding to  57  is  0.9980590875619341
# r2 score corresponding to  58  is  0.9979409805250542
# r2 score corresponding to  59  is  0.9988206408541043
# r2 score corresponding to  60  is  0.9983524624700004
# r2 score corresponding to  61  is  0.9986750140638304
# r2 score corresponding to  62  is  0.9984218447853509
# r2 score corresponding to  63  is  0.998548921928338
# r2 score corresponding to  64  is  0.9990774698172513
# r2 score corresponding to  65  is  0.999193684062838
# r2 score corresponding to  66  is  0.9989337666421959
# r2 score corresponding to  67  is  0.9992130696392953
# r2 score corresponding to  68  is  0.9990335668886922
# r2 score corresponding to  69  is  0.9979354437730034
# r2 score corresponding to  70  is  0.9991037006697541
# r2 score corresponding to  71  is  0.9983651562600553
# r2 score corresponding to  72  is  0.9987718958788778
# r2 score corresponding to  73  is  0.9985247894761172
# r2 score corresponding to  74  is  0.9989145963061307
# r2 score corresponding to  75  is  0.9986916347087419
# r2 score corresponding to  76  is  0.9988505287076301
# r2 score corresponding to  77  is  0.9992604288429598
# r2 score corresponding to  78  is  0.9992290325688538
# r2 score corresponding to  79  is  0.9989514859588139
# r2 score corresponding to  80  is  0.9988544995453751
# r2 score corresponding to  81  is  0.9990710001363362
# r2 score corresponding to  82  is  0.9985506253017382
# r2 score corresponding to  83  is  0.9993411712146509
# r2 score corresponding to  84  is  0.9980463556400818
# r2 score corresponding to  85  is  0.9982800943820155
# r2 score corresponding to  86  is  0.998908866577369
# r2 score corresponding to  87  is  0.9994344817177362
# r2 score corresponding to  88  is  0.9986088052045785
# r2 score corresponding to  89  is  0.9997306740765889
# r2 score corresponding to  90  is  0.9987850918044104
# r2 score corresponding to  91  is  0.9986463951092497
# r2 score corresponding to  92  is  0.9986964093370756
# r2 score corresponding to  93  is  0.9986740677345949
# r2 score corresponding to  94  is  0.9993192341764083
# r2 score corresponding to  95  is  0.9980190686105644
# r2 score corresponding to  96  is  0.9988835429973395
# r2 score corresponding to  97  is  0.9988169420013729
# r2 score corresponding to  98  is  0.9970237924729864
# r2 score corresponding to  99  is  0.998535692716571
# max r2 score corresponding to  89  is  0.9997306740765889
# 89

# %%
model_evaluation(knr,newx,y)
# Out:
# Mean r2 score for regressor:  0.9801090333388673
# standard deviation in r2 score for regressor:  0.028341448550935185
# [0.92420154 0.98894311 0.9888185  0.99867912 0.9999029 ]

# %%
#High r2 score is it due to multicollinearity

# %%
#lets choose our final model

# %%
x_train, x_test, y_train, y_test = train_test_split(newx, y,random_state = 48,test_size=0.20)
rfr=RandomForestRegressor(n_estimators=500)
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.0429167292602246
# r2_score is:  0.9990074269360872

# %%
import joblib
joblib.dump(rfr,'election.obj')
# Out:
# ['election.obj']
